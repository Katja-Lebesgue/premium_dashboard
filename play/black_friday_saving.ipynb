# %%
import sys
sys.path.append('..')
from datetime import datetime, date, timedelta
from dateutil.relativedelta import relativedelta

from tqdm import tqdm
from sqlalchemy import func
import webbrowser
import seaborn as sns
from matplotlib import ticker
from wordcloud import WordCloud
from collections import Counter
import matplotlib.dates as mdates
from matplotlib.colors import ListedColormap

from src.pingers import *
from src.models import *
from src import crud
from src.utils import *
from src.models.enums import CreativeType, TextType
from src.fb_api.get_preview_shareable_link import get_preview_shareable_link
from src.statistical_tests import mean_test


from src.database.session import db
metrics = (cr, ctr, cpm, roas)
df_path = f'/app/data/black_friday_{date.today()}.csv'
link_df_path = '/app/data/top_candiates.csv'

end_date = date.today()
start_date = date(year=2023, month=9, day=1)
sns.set_style("whitegrid", {'grid.linestyle': '--'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /app/play/black_friday_saving.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> start_date = date(year=2023, month=9, day=1)
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a> sns.set_style("whitegrid", {'grid.linestyle': '--'})
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> performance_columns
#
# NameError: name 'performance_columns' is not defined

# %%
ads_insights = ping_ads_insights_all_platforms(db=db, start_date=start_date-relativedelta(months=2), end_date=end_date+relativedelta(months=1), pivot=True, convert_to_datetime=False)
# Out:
# SELECT DISTINCT ON (currency_exchange_rate.code) currency_exchange_rate.code AS currency_exchange_rate_code, currency_exchange_rate.rate_from_usd AS currency_exchange_rate_rate_from_usd
# FROM currency_exchange_rate ORDER BY currency_exchange_rate.code, currency_exchange_rate.date DESC
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /app/play/black_friday_saving.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ads_insights = ping_ads_insights_all_platforms(db=db, start_date=start_date-relativedelta(months=2), end_date=end_date+relativedelta(months=1), pivot=True, convert_to_datetime=False)
#
# File /app/play/../src/pingers/ping_ads_insights.py:128, in ping_ads_insights_all_platforms(db, columns, monthly, shop_id, start_date, end_date, get_industry, convert_to_USD_bool, pivot, convert_to_datetime)
#     115 def ping_ads_insights_all_platforms(
#     116     db: Session,
#     117     columns: str | list[str] = ["spend", "revenue"],
#    (...)
#     125     convert_to_datetime: bool = True,
#     126 ) -> pd.DataFrame:
#     127     if convert_to_USD_bool:
# --> 128         conversion_json = crud.currency_exchange_rate.ping_current_rates_dict(db=db)
#     130     add_platform_prefix = not pivot
#     131     for idx, platform in enumerate((facebook_platform, google_platform, tiktok_platform)):
#
# File /app/play/../src/crud/currency_exchange_rate.py:77, in CRUDCurrencyExchangeRate.ping_current_rates_dict(self, db)
#      76 def ping_current_rates_dict(self, db: Session) -> dict:
# ---> 77     data = self.query_current_rates(db=db).all()
#      78     return {a.code: a.rate_from_usd for a in data}
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2768, in Query.all(self)
#    2752 def all(self):
#    2753     """Return the results represented by this :class:`_query.Query`
#    2754     as a list.
#    2755
#    (...)
#    2766             :ref:`faq_query_deduplicating`
#    2767     """
# -> 2768     return self._iter().all()
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2903, in Query._iter(self)
#    2900 params = self._params
#    2902 statement = self._statement_20()
# -> 2903 result = self.session.execute(
#    2904     statement,
#    2905     params,
#    2906     execution_options={"_sa_orm_load_options": self.load_options},
#    2907 )
#    2909 # legacy: automatically set scalars, unique
#    2910 if result._attributes.get("is_single_entity", False):
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1691, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, **kw)
#    1687     execution_options = execution_options.union(
#    1688         dict(future_result=False)
#    1689     )
#    1690 else:
# -> 1691     conn = self._connection_for_bind(bind)
#    1692 result = conn._execute_20(statement, params or {}, execution_options)
#    1694 if compile_state_cls:
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1532, in Session._connection_for_bind(self, engine, execution_options, **kw)
#    1529 TransactionalContext._trans_ctx_check(self)
#    1531 if self._transaction is not None or self._autobegin():
# -> 1532     return self._transaction._connection_for_bind(
#    1533         engine, execution_options
#    1534     )
#    1536 assert self._transaction is None
#    1537 assert self.autocommit
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/orm/session.py:747, in SessionTransaction._connection_for_bind(self, bind, execution_options)
#     742             raise sa_exc.InvalidRequestError(
#     743                 "Session already has a Connection associated for the "
#     744                 "given Connection's Engine"
#     745             )
#     746     else:
# --> 747         conn = bind.connect()
#     748         local_connect = True
#     750 try:
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3234, in Engine.connect(self, close_with_result)
#    3219 def connect(self, close_with_result=False):
#    3220     """Return a new :class:`_engine.Connection` object.
#    3221
#    3222     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3231
#    3232     """
# -> 3234     return self._connection_cls(self, close_with_result=close_with_result)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3313, in Engine.raw_connection(self, _connection)
#    3291 def raw_connection(self, _connection=None):
#    3292     """Return a "raw" DBAPI connection from the connection pool.
#    3293
#    3294     The returned object is a proxied version of the DBAPI
#    (...)
#    3311
#    3312     """
# -> 3313     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3278 dialect = self.dialect
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#    3282     if connection is None:
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:145, in QueuePool._do_get(self)
#     143         return self._create_connection()
#     144     except:
# --> 145         with util.safe_reraise():
#     146             self._dec_overflow()
#     147 else:
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/util/compat.py:207, in raise_(***failed resolving arguments***)
#     204     exception.__cause__ = replace_context
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#     212     del exception, replace_context, from_, with_traceback
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/pool/base.py:679, in _ConnectionRecord.__connect(self)
#     671     pool.dispatch.first_connect.for_modify(
#     672         pool.dispatch
#     673     ).exec_once_unless_exception(self.dbapi_connection, self)
#     675 # init of the dialect now takes place within the connect
#     676 # event, so ensure a mutex is used on the first run
#     677 pool.dispatch.connect.for_modify(
#     678     pool.dispatch
# --> 679 )._exec_w_sync_on_first_run(self.dbapi_connection, self)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/event/attr.py:329, in _CompoundListener._exec_w_sync_on_first_run(self, *args, **kw)
#     327 with self._exec_once_mutex:
#     328     try:
# --> 329         self(*args, **kw)
#     330     except:
#     331         raise
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/event/attr.py:343, in _CompoundListener.__call__(self, *args, **kw)
#     341     fn(*args, **kw)
#     342 for fn in self.listeners:
# --> 343     fn(*args, **kw)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:1691, in only_once.<locals>.go(*arg, **kw)
#    1689 once_fn = once.pop()
#    1690 try:
# -> 1691     return once_fn(*arg, **kw)
#    1692 except:
#    1693     if retry_on_exception:
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/create.py:694, in create_engine.<locals>.first_connect(dbapi_connection, connection_record)
#     687 finally:
#     688     # note that "invalidated" and "closed" are mutually
#     689     # exclusive in 1.4 Connection.
#     690     if not c.invalidated and not c.closed:
#     691         # transaction is rolled back otherwise, tested by
#     692         # test/dialect/postgresql/test_dialect.py
#     693         # ::MiscBackendTest::test_initial_transaction_state
# --> 694         dialect.do_rollback(c.connection)
#
# File /app/.venv/lib/python3.10/site-packages/sqlalchemy/engine/default.py:682, in DefaultDialect.do_rollback(self, dbapi_connection)
#     681 def do_rollback(self, dbapi_connection):
# --> 682     dbapi_connection.rollback()
#
# KeyboardInterrupt:

# %%
ads_insights.groupby(['year_month', 'platform']).sum(numeric_only=True).applymap(big_number_human_format)
# Out:
#                     shop_id    spend revenue
# year_month platform
# 2022-09    facebook  37.80G    6.87M  13.21M
#            google    36.03G    3.91M  16.07M
#            tiktok     1.88G  151.30K   1.15K
# 2022-10    facebook  38.53G    8.89M  16.97M
#            google    37.29G    4.36M  16.22M
#            tiktok     2.21G  125.31K   1.52K
# 2022-11    facebook  41.54G   10.55M  59.49M
#            google    37.55G    5.26M  22.59M
#            tiktok     2.92G   92.99K   1.63K
# 2022-12    facebook  38.30G    8.35M  40.44M
#            google    36.90G    4.84M  19.87M
#            tiktok     3.51G   82.77K   1.13K

# %%
fig, axs = plt.subplots(1, 2, sharey=True, sharex=True)
fig.tight_layout(pad=1.0)
fig.set_figwidth(10)
fig.set_figheight(3)
month_order = sorted(ads_insights.year_month.unique().tolist())
for idx, metric_col in enumerate(('spend', 'revenue')):
    ax = axs[idx]
    g = sns.barplot(data=ads_insights[ads_insights.platform != 'tiktok'], x='year_month', y=metric_col, hue='platform', palette='crest', order=month_order, errorbar=None, ax=ax, estimator=np.nansum)
    g.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: f'${big_number_human_format(x, big_decimals=0)}'))

# %%
def get_discounts(text: str) -> list:
    discounts = []
    discounts.extend([x.group() for x in re.finditer(r"(?i)(discount)\s(of\s)?()[\d]+\s?%", text)])
    discounts.extend([x.group() for x in re.finditer(r"(?i)(save)\s[\d]+\s?%", text)])
    discounts.extend([x.group() for x in re.finditer(r"(?i)[\d]+\s?%\s?(off)", text)])
    discounts.extend([x.group() for x in re.finditer(r"(?i)[\d]+\s?%\s(discount)", text)])
    discounts.extend([x.group() for x in re.finditer(r"(?i)-[\d]+\s?%", text)])
    return discounts

# %%
force_from_scratch = False
if not os.path.exists(df_path) or force_from_scratch:
    print('Tu sam')
    query = db.query(FacebookDailyPerformance.ad_id).filter(
        FacebookDailyPerformance.date_start.between(start_date, end_date),
    ).group_by(FacebookDailyPerformance.ad_id).having(func.sum(FacebookDailyPerformance.spend) > 500)
    ad_ids_df = read_query_into_df(db=db, query=query, chunk_size=10000)
    ad_ids = ad_ids_df.ad_id.tolist()
    df = ping_facebook_creative_target_and_performance(
        db=db, ad_id=ad_ids, start_date=start_date, end_date=end_date, period=Period.date
    )

    for metric in metrics:
        df[str(metric)] = df.apply(metric.formula_series, axis=1)

    #add discount data
    for text_type in TextType:
        df[f"{text_type}_discounts"] = df[f"{text_type}"].apply(
            lambda texts: sum([get_discounts(text) for text in texts], [])
        )
    df["discounts"] = df.apply(
        lambda row: sum([row[f"{text_type}_discounts"] for text_type in TextType], []), axis=1
    )
    df["discount_values"] = df["discounts"].apply(
        lambda discounts: [int(re.findall("\d+", discount)[0]) for discount in discounts]
    )

    df['discount_value'] = df.discount_values.apply(lambda l: l[0] if len(l) else None)

    access_tokens_dict = {
        shop_id: access_token
        for shop_id in df.shop_id.unique().tolist()
        if (access_token := crud.credentials.get_facebook_access_token_by_shop(db=db, shop_id=shop_id))
        is not None
    }
    df.to_csv(df_path, index=False)
df = read_csv_and_eval(df_path)

# filter US ads
df = df[df.countries.apply(lambda l: len(l)) == 1]
df = df[df.countries.apply(lambda l: l[0]) == 'US']

#broken conversion
df = df[df.CR.apply(lambda x: x in cr.interval) & df.CTR.apply(lambda x: x in ctr.interval)]
df = df[df.ROAS.between(100, 7000)]
df = df[df.creative_type != CreativeType.unknown]
df = df.fillna(value={'discount_value': 0},).count()

# %%
discounts_by_date = df.groupby(df.date).apply(lambda df: df.discount_value.value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /app/play/black_friday_saving.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X61sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> discounts_by_date = df.groupby(df.date).apply(lambda df: df.discount_value[df.discount_value.notna()].value_counts())
#
# File /app/.venv/lib/python3.10/site-packages/pandas/core/series.py:2064, in Series.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    2061     raise TypeError("as_index=False only valid with DataFrame")
#    2062 axis = self._get_axis_number(axis)
# -> 2064 return SeriesGroupBy(
#    2065     obj=self,
#    2066     keys=by,
#    2067     axis=axis,
#    2068     level=level,
#    2069     as_index=as_index,
#    2070     sort=sort,
#    2071     group_keys=group_keys,
#    2072     observed=observed,
#    2073     dropna=dropna,
#    2074 )
#
# File /app/.venv/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#     928 self.dropna = dropna
#     930 if grouper is None:
# --> 931     grouper, exclusions, obj = get_grouper(
#     932         obj,
#     933         keys,
#     934         axis=axis,
#     935         level=level,
#     936         sort=sort,
#     937         observed=observed,
#     938         dropna=self.dropna,
#     939     )
#     941 self.obj = obj
#     942 self.axis = obj._get_axis_number(axis)
#
# File /app/.venv/lib/python3.10/site-packages/pandas/core/groupby/grouper.py:985, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#     983         in_axis, level, gpr = False, gpr, None
#     984     else:
# --> 985         raise KeyError(gpr)
#     986 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     987     # Add key to exclusions
#     988     exclusions.add(gpr.key)
#
# KeyError: 19100

# %%
a = sns.color_palette('crest')
color_pallete = sns.color_palette([(0.761, 0.039, 0.3)] + sns.color_palette('crest'))
color_pallete

# %%
unstacked_df = discounts_by_date.unstack(level='discount_value')
ax = unstacked_df.plot(kind='bar', stacked=True, colormap=ListedColormap(color_pallete.as_hex()))
ax.xaxis.set_major_locator(mdates.DayLocator(interval=10))

# %%
tmp_df = pd.DataFrame(
    data=[["e1", "f1"], ["e2", "f2"]],
    index=pd.MultiIndex.from_tuples([("a1", "b1", "c1"), ("a2", "b2", "c2")], names=['a', 'b', 'c']),
    columns=['e', 'f']
)
tmp_df.unstack('c')
# Out:
#          e         f
# c       c1   c2   c1   c2
# a  b
# a1 b1   e1  NaN   f1  NaN
# a2 b2  NaN   e2  NaN   f2

# %%
tmp_df = pd.DataFrame(data=[0, 1, 2], index=[2, 3, 3])
tmp_df.unstack().index
# Out:
# MultiIndex([(0, 2),
#             (0, 3),
#             (0, 3)],
#            )

# %%
tmp_df
# Out:
#    0
# 2  0
# 3  1

# %%
discounts_by_date.plot(kind='bar', stacked=True)
# Out:
# <Axes: >

# %%
df.ROAS
# Out:
# 0       118.282070
# 1       123.239780
# 2       545.778512
# 3       267.246683
# 4       106.053282
#            ...
# 1893    107.881914
# 1894    302.670720
# 1895    197.988818
# 1896    384.706694
# 1897    172.448150
# Name: ROAS, Length: 1898, dtype: float64

# %%
df.groupby('creative_type').apply(lambda df: df.shop_id.nunique())
# Out:
# creative_type
# carousel    56
# dynamic     68
# image       28
# video       27
# dtype: int64

# %%
df.creative_type.value_counts()
# Out:
# creative_type
# dynamic     385
# carousel    236
# image       109
# video        97
# Name: count, dtype: int64

# %%
df.shop_id.nunique()
# Out:
# 104

# %%
len(df)
# Out:
# 1898

# %%
plot_df = df

fig, axs = plt.subplots(2, 2, sharex=True)
fig.tight_layout(pad=2.0)
fig.set_figwidth(10)
fig.set_figheight(6)
for idx, metric in enumerate(metrics):
    ax = axs[idx//2, idx%2]
    g = sns.boxplot(data=df, x='creative_type', hue='creative_type', y=str(metric), palette='crest', showfliers=False, ax=ax)
    g.yaxis.set_major_formatter(ticker.FuncFormatter(metric.format_ticker))
    for tick in ax.get_xticklabels():
        tick.set_rotation(90)
plt.show()

# %%
creative_types = [ct for ct in get_enum_values(CreativeType) if ct not in (CreativeType.unknown, CreativeType.image)]
grouped_df = df.groupby('creative_type')
sample_dict = {ct: grouped_df.get_group(ct)['ROAS'].to_list() for ct in creative_types}

# %%
mean_test(samples_dict=sample_dict)
# Out:
# {'stat': 1.822952597191943,
#  'p': 0.4019304165133031,
#  'test_type': 'kruskal',
#  'stat_levene': 0.542599984593804,
#  'p_levene': 0.5814742256595419,
#  'video': {'mean': 399.70656570842254, 'size': 97},
#  'dynamic': {'mean': 371.36442063525726, 'size': 385},
#  'carousel': {'mean': 348.83248988130487, 'size': 236}}

# %%
mean_test()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /app/play/black_friday_saving.ipynb Cell 14 line 1
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mean_test()
#
# TypeError: mean_test() missing 1 required positional argument: 'samples_dict'

# %%
big_number_human_format(num=5_000_000, big_decimals=0)
# Out:
# '5M'

# %%
top_candidates = df[(df.days_active > 5) & (df.spend_USD > 800) & (df.creative_type != CreativeType.unknown)]
top_candidates = (
    top_candidates.groupby(['shop_id', "creative_type"]).apply(lambda df: df.nlargest(1, "ROAS")).reset_index(drop=True)
).groupby(['creative_type']).apply(lambda df: df.nlargest(6, "ROAS")).reset_index(drop=True)

# %%
top_candidates.shop_id.nunique()
# Out:
# 19

# %%
# adding links
top_candidates = top_candidates[top_candidates.shop_id.isin(access_tokens_dict.keys())]
top_candidates["preview_link"] = top_candidates.apply(
    lambda row: get_preview_shareable_link(ad_id=row.ad_id, access_token=access_tokens_dict[row.shop_id]), axis=1
)
top_candidates.to_csv('/app/data/top_candiates.csv', index=False)
# for link in top_candidates.preview_link:
#     if link is not None and len(link):
#         webbrowser.open(link)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /app/play/black_friday_saving.ipynb Cell 18 line 2
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # adding links
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> top_candidates = top_candidates[top_candidates.shop_id.isin(access_tokens_dict.keys())]
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> top_candidates["preview_link"] = top_candidates.apply(
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     lambda row: get_preview_shareable_link(ad_id=row.ad_id, access_token=access_tokens_dict[row.shop_id]), axis=1
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> )
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f7072656d69756d5f64617368626f6172642d7072656d69756d5f64617368626f6172642d31222c2273657474696e6773223a7b22636f6e74657874223a226465736b746f702d6c696e7578227d7d/app/play/black_friday_saving.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> top_candidates.to_csv('/app/data/top_candiates.csv', index=False)
#
# NameError: name 'access_tokens_dict' is not defined

# %%
top_discount_candidates = df[(df.days_active > 5) & (df.spend_USD > 800) & (df.creative_type != CreativeType.unknown) & (df.discount)]

# %%
hmm = top_discount_candidates.nlargest(50, 'ROAS')
len(hmm[hmm.discount_value <= 50])
# Out:
# 44

# %%
sns.color_palette('crest')[5]
# Out:
# (0.14573579, 0.29354139, 0.49847009)

# %%
sns.set_style("whitegrid", {'grid.linestyle': '--'})
metric = cr
# sns.reset_defaults()
fig, axs = plt.subplots(1, 1, sharex=True)
fig.tight_layout(pad=1.0)
fig.set_figwidth(5)
fig.set_figheight(5)
g = sns.boxplot(data=df, x='creative_type', y=str(metric), palette='crest', showfliers=False, ax=axs)
plt.show()
# Out:
# /tmp/ipykernel_11997/2002189826.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   g = sns.boxplot(data=df, x='creative_type', y=str(metric), palette='crest', showfliers=False, ax=axs)

# %%
sns.set_style("whitegrid", {'grid.linestyle': '--'})
fig, axs = plt.subplots(1, 1, sharex=True)
fig.tight_layout(pad=1.0)
fig.set_figwidth(6)
fig.set_figheight(4)
sns.histplot(data=top_discount_candidates.nlargest(50, 'ROAS'), x='discount_value', color=sns.color_palette('crest')[4], ax=axs)
plt.show()
plt.show()

# %%
sns.set_style("whitegrid", {'grid.linestyle': '--'})
sns.histplot(x=[1, 2, 3, 3, 4])
plt.show()

# %%
top_candidates
# Out:
#       shop_id         account_id              ad_id creative_type  \
# 0    24268796           59007194      6275976606248      carousel
# 1    45446054    401446117114204  23848968468360720      carousel
# 2    45514705           46057363      6277072116977      carousel
# 3    45867058           94834424      6299704875375      carousel
# 4   101977442    441336120473519  23852306074820767      carousel
# 5    42535592    613242333127020  23851002390100200      carousel
# 6   131759935    303750601774224  23852204424710223       dynamic
# 7    46167900    452791872345451  23847969539090303       dynamic
# 8    45514705           46057363      6276942847977       dynamic
# 9   128852272   1005922726532575  23852577950010083       dynamic
# 10   98396173   1517444545053682  23852665727380196       dynamic
# 11   16200158   1476095925924848  23852765208380627       dynamic
# 12   46167900    452791872345451  23850956604670303         image
# 13   96659600    100890696662779      6330081691123         image
# 14  104863738   2259772387660145  23851956328370234         image
# 15   35134105   2645838925449830  23852365109070757         image
# 16      16038    923409341101559  23849051466390755         image
# 17  108039525    355948925380246  23851306031570132         image
# 18   15433380    740587486140754  23852585265750023         video
# 19   46167900    452791872345451  23850604365270303         video
# 20   42535592    613242333127020  23851289923540200         video
# 21   45514705           46057363      6245431640177         video
# 22   83029637    566347693441298      6308597615817         video
# 23   95900816  10152041600798842  23851761274470269         video
#
#                                                 title  \
# 0                                  [{{product.name}}]
# 1                                  [{{product.name}}]
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6   [Save USD 408 on Rotimatic+, Biggest Discount ...
# 7       [Tumble | Machine Washable & Spillproof Rugs]
# 8   [The best gift for a safer and cozier night’s ...
# 9   [Early Black Friday Sale! Save up to $3500 On ...
# 10                                                 []
# 11                                 [25% Off Sitewide]
# 12              [Free shipping. Free 30-day returns.]
# 13                 [Limited-Edition Blueberry Coffee]
# 14                                    [UP TO 50% OFF]
# 15                       [40% Off—100% of the Impact]
# 16                             [Shop for 50-80% less]
# 17                          [Vibration Plate Therapy]
# 18           [Black Friday Sale | Extra 30% Off Sale]
# 19                 [Wipe away your tears (and mess).]
# 20                          [Extra Fupa compression!]
# 21    [Better sleep for baby & peace of mind for you]
# 22  [Retro Roller - Nostalgic Mani for as little a...
# 23                      [Black Friday | Cyber Monday]
#
#                                               primary  \
# 0   [Still thinking? Here's your 5% OFF discount.\...
# 1   [#1 Mont Alpi Grill Retailer - Free Shipping O...
# 2   [✨ 20% OFF EVERYTHING! ✨ Grab your favorite me...
# 3                                                  []
# 4   [NOW OR NEVER: Our Hottest Deals of the Year 🔥...
# 5           [Custom made shorts / Capris- high waist]
# 6   [USD 408 OFF on Rotimatic Plus as Black Friday...
# 7   [Considering a Spillproof & Machine Washable T...
# 8   [✨ 20% OFF EVERYTHING! ✨ Grab your favorite me...
# 9   [Don't wait for spring to arrive before you bu...
# 10  [All we want is beautiful, ultra-soft bedding ...
# 11  [Our biggest sale of the year is here. Get 25%...
# 12  [Did you know our rugs come with our one-of-a-...
# 13  [Like a Thick Slice of Blueberry Coffee Cake—g...
# 14  [For a limited time only get up to 50% OFF Mon...
# 15  [Shop extra good this holiday season with bags...
# 16  [If you’re only going to put one thing on, rea...
# 17  [Dr. Terry Wahls, a pioneer in MS research and...
# 18  [Shop our Black Friday sale and take an extra ...
# 19  [Say goodbye to scrubbing with Tumble's spillp...
# 20  [Client review - Tributo Custom Faja 1017 bra ...
# 21  [Merino wool sleep bags designed to help baby ...
# 22  [Watch @kayla.kingsberry create a GROOVY mani ...
# 23  [Our Black Friday and Cyber Monday offer has a...
#
#                                           description    cta  discount  emoji  \
# 0             [{{product.current_price strip_zeros}}]  False      True  False
# 1                                                  []  False     False  False
# 2         [Don't miss this!, Don't miss it!, 20% OFF]  False      True   True
# 3                                                  []  False     False  False
# 4   [Luxury K9 Crystal & Stainless Steel crystal c...  False      True   True
# 5   [Custom-made shorts that offer control of your...  False     False  False
# 6                         [Hurry! Limited Time Offer]  False      True  False
# 7                                   [Rugs Reimagined]  False     False  False
# 8                                  [Don't miss this!]  False      True   True
# 9                                                  []   True      True   True
# 10                                                 []  False     False   True
# 11                                   [Use Code: BF22]  False      True   True
# 12                                                 []  False     False   True
# 13                                                 []  False     False  False
# 14                                                 []  False      True   True
# 15                          [FREE Shipping Over $100]  False      True  False
# 16                                            [⭐⭐⭐⭐⭐]  False      True   True
# 17                                                 []  False     False   True
# 18                                                 []  False      True  False
# 19                                                 []  False     False   True
# 20  [Perfect faja to achieve hourglass shape after...  False     False  False
# 21    [FREE shipping on orders $49+ and easy returns]  False     False   True
# 22                                                 []  False     False   True
# 23                   [Free Gift + Free U.S. Shipping]  False     False  False
#
#     ...         CR       CTR        CPM         ROAS  description_discounts  \
# 0   ...   3.919308  1.823130   9.446546  6013.583021                     []
# 1   ...   0.255646  4.326347  22.259212  3382.248207                     []
# 2   ...  30.915371  0.794893  18.739429  1615.812686              [20% OFF]
# 3   ...  54.569191  0.794721  23.190505  1160.913369                     []
# 4   ...   0.373134  2.958547  26.596291   960.443711                     []
# 5   ...   6.519337  1.052118  14.265901   842.996960                     []
# 6   ...   6.672761  2.583723  38.106294  4948.693785                     []
# 7   ...  10.304054  1.452868  28.260731  1644.674957                     []
# 8   ...  40.073529  0.792525  21.782599  1581.887657                     []
# 9   ...   0.128949  2.254393  13.810811  1361.545829                     []
# 10  ...  14.563107  0.324778  26.287129  1054.756678                     []
# 11  ...  32.848233  1.784853  34.625775  1050.448491                     []
# 12  ...  12.626263  1.331674  36.032048  1517.408550                     []
# 13  ...  50.332005  0.450566   9.539262  1376.468264                     []
# 14  ...   2.090209  3.027679  33.019352   765.448786                     []
# 15  ...  12.698413  2.062868  53.449574   684.090422                     []
# 16  ...  42.647059  0.217450  37.356539   452.713802                     []
# 17  ...   7.090465  0.750335  28.429495   397.719935                     []
# 18  ...   5.768164  4.291529  22.121962  1512.229264                     []
# 19  ...  12.365591  1.438877  40.237879  1391.346644                     []
# 20  ...   2.817783  2.726024  16.569853   980.741099                     []
# 21  ...  17.487685  0.694837  15.332272   877.202304                     []
# 22  ...  12.009063  2.135691  16.269316   866.112433                     []
# 23  ...  19.784173  0.968169  60.212788   771.233408                     []
#
#                              primary_discounts  title_discounts  \
# 0                                     [5% OFF]               []
# 1                                           []               []
# 2                                    [20% OFF]               []
# 3                                           []               []
# 4                  [50% OFF, 40% OFF, 40% OFF]               []
# 5                                           []               []
# 6                                    [45% OFF]               []
# 7                                           []               []
# 8                                    [20% OFF]               []
# 9   [20% Discount, 20% Discount, 20% Discount]               []
# 10                                          []               []
# 11                                   [25% off]        [25% Off]
# 12                                          []               []
# 13                                          []               []
# 14                                   [50% OFF]        [50% OFF]
# 15                                   [40% off]        [40% Off]
# 16                                          []           [-80%]
# 17                                          []               []
# 18                                   [30% off]        [30% Off]
# 19                                          []               []
# 20                                          []               []
# 21                                          []               []
# 22                                          []               []
# 23                                          []               []
#
#                                      discounts  discount_values  \
# 0                                     [5% OFF]              [5]
# 1                                           []               []
# 2                           [20% OFF, 20% OFF]         [20, 20]
# 3                                           []               []
# 4                  [50% OFF, 40% OFF, 40% OFF]     [50, 40, 40]
# 5                                           []               []
# 6                                    [45% OFF]             [45]
# 7                                           []               []
# 8                                    [20% OFF]             [20]
# 9   [20% Discount, 20% Discount, 20% Discount]     [20, 20, 20]
# 10                                          []               []
# 11                          [25% off, 25% Off]         [25, 25]
# 12                                          []               []
# 13                                          []               []
# 14                          [50% OFF, 50% OFF]         [50, 50]
# 15                          [40% off, 40% Off]         [40, 40]
# 16                                      [-80%]             [80]
# 17                                          []               []
# 18                          [30% off, 30% Off]         [30, 30]
# 19                                          []               []
# 20                                          []               []
# 21                                          []               []
# 22                                          []               []
# 23                                          []               []
#
#     discount_value
# 0              5.0
# 1              NaN
# 2             20.0
# 3              NaN
# 4             50.0
# 5              NaN
# 6             45.0
# 7              NaN
# 8             20.0
# 9             20.0
# 10             NaN
# 11            25.0
# 12             NaN
# 13             NaN
# 14            50.0
# 15            40.0
# 16            80.0
# 17             NaN
# 18            30.0
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
#
# [24 rows x 47 columns]

# %%
top_discount_candidates.nlargest(50, 'ROAS').discount_value.hist()
# Out:
# <Axes: >

# %%
top_discount_candidates.creative_type.value_counts() / df.creative_type.value_counts()
# Out:
# creative_type
# dynamic     0.220779
# carousel    0.194915
# image       0.201835
# video       0.144330
# Name: count, dtype: float64

# %%
df.creative_type.value_counts()
# Out:
# creative_type
# dynamic     385
# carousel    236
# image       109
# video        97
# Name: count, dtype: int64

# %%
df.groupby('creative_type').apply(lambda df: df.shop_id.nunique())
# Out:
# creative_type
# carousel    56
# dynamic     68
# image       28
# video       27
# dtype: int64

# %%
link_df = read_csv_and_eval(link_df_path)

# %%
creative_type_links_dict = {ct: link_df.loc[link_df.creative_type == ct, 'preview_link'].dropna().tolist() for ct in link_df.creative_type.unique().tolist()}

# %%
creative_type_links_dict
# Out:
# {'carousel': ['https://fb.me/1ELl50WuZkRh17v',
#   'https://fb.me/1F9zWwVClltpVVl',
#   'https://fb.me/22irTsHAZngWvHj',
#   'https://fb.me/1MFuMSxMq39RlI2',
#   'https://fb.me/1Frdi8tZDr3zOO7'],
#  'dynamic': ['https://fb.me/9jDarQxDS3E8pW',
#   'https://fb.me/1UrLx4fW3UKV1YP',
#   'https://fb.me/1GBkmmFie4IK2b5',
#   'https://fb.me/1ZcUcBCIOkTqdUi',
#   'https://fb.me/1VVJxIRJqQCJ3Nu'],
#  'image': ['https://fb.me/1FRmZrfANkb5yWT',
#   'https://fb.me/1NJlwswhVz4Niay',
#   'https://fb.me/b0RyExxcDIvVah',
#   'https://fb.me/bq8LJLQMoVwSEi'],
#  'video': ['https://fb.me/25TrLMIB2ddadly',
#   'https://fb.me/1MXqvjk2caFrvNe',
#   'https://fb.me/1RdC7nIoRFy0qZb',
#   'https://fb.me/1Fhz2iX6dc6vll2',
#   'https://fb.me/1R1VPJGoppgSuZa']}

# %%
print('\n'.join([ct + '\n' + '\n'.join(creative_type_links_dict[ct]) for ct in creative_type_links_dict.keys()]))
# Out:
# carousel
# https://fb.me/1ELl50WuZkRh17v
# https://fb.me/1F9zWwVClltpVVl
# https://fb.me/22irTsHAZngWvHj
# https://fb.me/1MFuMSxMq39RlI2
# https://fb.me/1Frdi8tZDr3zOO7
# dynamic
# https://fb.me/9jDarQxDS3E8pW
# https://fb.me/1UrLx4fW3UKV1YP
# https://fb.me/1GBkmmFie4IK2b5
# https://fb.me/1ZcUcBCIOkTqdUi
# https://fb.me/1VVJxIRJqQCJ3Nu
# image
# https://fb.me/1FRmZrfANkb5yWT
# https://fb.me/1NJlwswhVz4Niay
# https://fb.me/b0RyExxcDIvVah
# https://fb.me/bq8LJLQMoVwSEi
# video
# https://fb.me/25TrLMIB2ddadly
# https://fb.me/1MXqvjk2caFrvNe
# https://fb.me/1RdC7nIoRFy0qZb
# https://fb.me/1Fhz2iX6dc6vll2
# https://fb.me/1R1VPJGoppgSuZa

# %%
link_df.shop_id.nunique()
# Out:
# 14

# %%
plt.figure(figsize=(5, 5))
discount_text = sum(df[df.discount].discounts.tolist(), [])
wc = WordCloud(
    background_color="black",
    stopwords=set("hey"),
    include_numbers=True,
    font_path=f"{os.getenv('GLOBAL_PATH_TO_REPO')}/data/Montserrat/static/Montserrat-Medium.ttf",
    colormap='crest'
).generate_from_frequencies(frequencies=dict(Counter(discount_text)))
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
discount_text
# Out:
# '25% off, 40% Off, 40% OFF, 40% Off, 40% OFF, -80%, -80%, 10% off, 40% Off, 40% off, 15% off, -80%, 20% off, 20% Off, -80%, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 10% Off, Save 20%, 20% Off, 10% off, 10% off, 10% off, 10% off, 10% off, 30% Off, 40% Off, 40% OFF, 40% Off, 40% OFF, 20% off, 20% off, 20% Off, 20% off, -10%, 10% off, 10% OFF, 20% Off, 20% off, -10%, 15% off, 25% off, 65% Off, 65% OFF, 15% off, 15% off, 30% OFF, 50% Off, 50% Off, 30% Off, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 25% Off, 25% Off, 30% Off, 30% Off, 21% off, 40% OFF, 40% OFF, 50% OFF, 50% OFF, 50% off, 50% OFF, 15% off, 20% off, 20% OFF, 70% off, -80%, -80%, 55% OFF, 55% OFF, -80%, -80%, 20% OFF, 10% OFF, SAVE 10%, 10% OFF, SAVE 10%, -80%, 50% off, 50% OFF, 10% OFF, SAVE 10%, 20% OFF, 40% off, -40%, 40% off, -40%, 40% off, -40%, 40% off, -40%, 30% off, 30% off, 15% off, 50% Off, 30% OFF, 40% Off, 50% OFF, 50% OFF, 30% off, 30% off, 30% Off, 30% off, 30% off, 30% off, 20% Off, 25% off, 25% off, 25% OFF, 50% off, 50% off, 50% off, 30% off, 30% off, 30% off, 30% Off, 30% off, 30% off, 30% off, 30% off, 30% Off, 25% off, 25% off, 25% off, 25% off, 25% off, 30% off, 10% OFF, 10% OFF, 10% OFF, 45% OFF, 45% OFF, 15% off, 15% off, 15% Off, 30% off, 30% off, 20% OFF, 20% OFF, -20%, 70% OFF, 50% off, 50% Off, 50% Off, 50% off, 50% Off, 30% OFF, 50% Off, 50% Off, 30% Off, 41% off, 20% OFF, 41% off, 20% OFF, 41% off, 20% OFF, 50% off, 41% off, 20% OFF, Save 30%, Save 30%, Save 30%, 25% Off, 25% Off, 10% off, 70% OFF, 70% OFF, 60% Off, 60% OFF, 60% OFF, Save 15%, 50% Off, 50% OFF, 40% OFF, 40% OFF, 10% discount, 40% OFF, 40% Off, 40% OFF, 40% Off, 40% OFF, 40% Off, 40% OFF, 40% Off, save 15%, save 20%, Save 25%, 30% off, 40% off, 40% Off, 40% off, 50% off, 50% off, 50% Off, 50% off, 50% Off, 40% off, 40% off, 40% Off, 40% Off, 40% off, 40% Off, 50% off, 50% Off, 50% off, 50% Off, 50% off, 40% off, 50% off, 50% Off, 50% off, 25% off, 25% OFF, 25% off, 25% OFF, 50% off, 50% OFF, 30% OFF, 30% Off, 30% OFF, 30% Off, 20% off, 20% OFF, 15% off, 20% off, 20% OFF, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 50% OFF, 15% OFF, 10% discount, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 25% OFF, 25% OFF, 25% off, 25% OFF, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 40% off, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 20% Discount, 25% off, 25% Off, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 25% off, 25% Off, 25% off, 25% Off, 25% off, 25% Off, 25% off, 25% Off, 25% off, 25% Off, 25% off, 25% Off, 40% OFF, 40% OFF, 25% off, 25% Off, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 60% OFF, 25% Off, 25% OFF, 25% OFF, 25% OFF, 25% OFF, 25% off, 25% Off, 25% off, 25% Off, 60% OFF, 60% OFF, 60% OFF, 70% OFF, 70% OFF, 70% OFF, 60% OFF, 60% OFF, 60% OFF, 40% off, 40% off, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 70% OFF, 50% off, 50% off, 50% off, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 40% off, 25% OFF, 40% off, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 25% OFF, 25% OFF, 25% OFF, 25% off, 25% OFF, 25% off, 25% OFF, 40% off, 25% off, 25% OFF, 40% off, 25% off, 25% OFF, 10% off, save 10%, 15% off, 15% off, 20% OFF, 20% OFF, 20% OFF, 20% OFF, 20% OFF, 20% OFF, 15% OFF, 20% OFF, 20% OFF, 15% OFF, Save 15%, Save 15%, 5% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF, 50% OFF ...
